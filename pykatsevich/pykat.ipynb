# %%
import astra

print("astra.__version__ =", getattr(astra, "__version__", "unknown"))
print("astra.use_cuda()  =", astra.use_cuda())  # English comment: True means CUDA backend enabled

astra.test()  # English comment: basic installation self-test (may be slow)
# Out:
# astra.__version__ = unknown
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 import astra
#       3 print("astra.__version__ =", getattr(astra, "__version__", "unknown"))
# ----> 4 print("astra.use_cuda()  =", astra.use_cuda())  # English comment: True means CUDA backend enabled
#       6 astra.test()
#
# AttributeError: module 'astra' has no attribute 'use_cuda'
